# %% [markdown]
# # IIE4123 HW2
# ## Kichang Lee(2019193016), School of Integrated Technology, Yonsei Univ
#
# Language : Python3(Python 3.9.7 64-bit)
#
# OS : Microsoft Windows 10 Education (10.0.19042)
#
# Environment
#
# CPU : Intel(R) Core(TM) i9-10850K CPU 3.60GHz, 3600Mhz, 10 Core with Intel(R) UHD Graphics 630
#
# RAM : 64GB
#
# GPU : RTX3090
#
# ## Notes about Task3
#
# I used a model with sigmoid function that I used in task2 but with out the batch normalization.
#
# (a) One with the preprocessing works better. In all the aspect of loss value and accuracy also the learning speed.
#
# (b) The rescaled data heps the model to learn better than one with the integer value. Preprocessing let the model to treat all the images in the same manner and let them contiributes more evenly to the total loss.

# %% [markdown]
# # Import Packages

# %%
import time

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Hyper-Parameters

# %%
BATCH_SIZE = 100
LEARNING_RATE = 0.001
EPOCHS = 50


USE_CUDA = torch.cuda.is_available() 
DEVICE = torch.device("cuda" if USE_CUDA else "cpu") 
print("다음 기기로 학습합니다:", DEVICE)
# Out:
# 다음 기기로 학습합니다: cuda

# %% [markdown]
# # Data Management

# %%
transform = transforms.Compose([transforms.ToTensor()]) # Rescaled into [0,1]

whole_train_set = dset.MNIST("./MNIST_data", train=True, transform=transform, download=False)
mnist_test = dset.MNIST("./MNIST_data", train=False, transform=transform, download=False)

mnist_train, mnist_val = train_test_split(whole_train_set, test_size = 0.1, stratify=whole_train_set.targets)

train_loader = torch.utils.data.DataLoader(mnist_train, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
val_loader = torch.utils.data.DataLoader(mnist_val, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)
test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)
# Out:
# C:\Users\Kichang\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torchvision\datasets\mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %% [markdown]
# # Model

# %%
class MLP(nn.Module):
    def __init__(self, activation_function):
        super(MLP, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Linear(784, 15, bias=True),
            activation_function
        )
        self.layer2 = nn.Sequential(
            nn.Linear(15, 12, bias=True),
            activation_function
        )
        self.layer3 = nn.Sequential(
            nn.Linear(12, 12, bias=True),
            activation_function
        )
        self.layer4 = nn.Sequential(
            nn.Linear(12, 10, bias=True),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        x = x.view(x.size(0), -1) # flatten
        x_out = self.layer1(x)
        x_out = self.layer2(x_out)
        x_out = self.layer3(x_out)        
        x_out = self.layer4(x_out)
        return x_out
        
def weights_init(m):
    if isinstance(m, nn.Linear):
        nn.init.normal_(m.weight, mean=0.0, std=0.01)
        nn.init.constant_(m.bias, 0)

# %%
models = [ MLP(nn.Sigmoid()).apply(weights_init).to(DEVICE), MLP(nn.Sigmoid()).apply(weights_init).to(DEVICE) ]#MLP(nn.ReLU()).apply(weights_init).to(DEVICE), MLP(nn.Sigmoid()).apply(weights_init).to(DEVICE)]
criterion = nn.CrossEntropyLoss().to(DEVICE)

# %%
LOSSES_TRAIN, LOSSES_VAL, LOSSES_TEST = [[] for idx in range(len(models))], [[] for idx in range(len(models))], [[] for idx in range(len(models))]
ACCS_VAL, ACCS_TEST = [[] for idx in range(len(models))], [[] for idx in range(len(models))]

GRAD_MAG = [[] for idx in range(len(models))]

for model_idx, model in enumerate(models):
    dict_param = dict()
    for name, params in model.named_parameters():
        dict_param[name] = []
    GRAD_MAG[model_idx] = dict_param

# %%
for model_idx, model in enumerate(models):
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    train_sample_num = len(train_loader)
    val_sample_num = len(val_loader)

    start = time.time()
    for epoch in tqdm(range(EPOCHS), desc="EPOCHS"):
        model.train()
        LOSS_TRACE_FOR_TRAIN, LOSS_TRACE_FOR_VAL, LOSS_TRACE_FOR_TEST = [], [], []
        for idx, batch in enumerate(train_loader):
            optimizer.zero_grad()
            
            if model_idx == 0:
                X_train, Y_train = batch[0]*255, batch[1]
            else:
                X_train, Y_train = batch
            X_train, Y_train = X_train.to(DEVICE), Y_train.to(DEVICE)

            Y_pred_train = model(X_train)
            Y_train = Y_train.squeeze(-1)

            LOSS_train = criterion(Y_pred_train, Y_train)

            LOSS_TRACE_FOR_TRAIN.append(LOSS_train.cpu().detach().numpy())
            LOSS_train.backward()
            optimizer.step()
            # for name, params in model.named_parameters():
            #     if type(params.grad) != None:
            #         GRAD_MAG[model_idx][name].append(((sum(sum((params.grad**2)**0.5))/params.numel()).cpu().detach().numpy() if len(params.size()) == 2 else (sum((params.grad**2)**0.5)/params.numel()).cpu().detach().numpy()))
            # #print(name, '\n', (sum(sum((params.grad**2)**0.5))/params.numel() if len(params.size()) == 2 else sum((params.grad**2)**0.5)/params.numel()), '\n')

        with torch.no_grad():
            model.eval()

            Result_pred_val, Result_anno_val = [], []
            for idx, batch in enumerate(val_loader):
                if model_idx == 0:
                    X_val, Y_val = batch[0]*255, batch[1]
                else:
                    X_val, Y_val = batch
                X_val, Y_val = X_val.to(DEVICE), Y_val.to(DEVICE)

                Y_pred_val = model(X_val)
                Y_val = Y_val.squeeze(-1)
                LOSS_val = criterion(Y_pred_val, Y_val)

                LOSS_TRACE_FOR_VAL.append(LOSS_val.cpu().detach().numpy())

                Y_pred_val_np  = Y_pred_val.to('cpu').detach().numpy()
                Y_pred_val_np  = np.argmax(Y_pred_val_np, axis=1).reshape(-1, 1)
                Y_val_np       = Y_val.to('cpu').detach().numpy().reshape(-1, 1)

                Result_pred_val.append(list(Y_pred_val_np[0]))
                Result_anno_val.append(list(Y_val_np[0]))
            
            Result_pred_test, Result_anno_test = [], []
            for idx, batch in enumerate(test_loader):
                if model_idx == 0:
                    X_test, Y_test = batch[0]*255, batch[1]
                else:
                    X_test, Y_test = batch
                X_test, Y_test = X_test.to(DEVICE), Y_test.to(DEVICE)

                Y_pred_test = model(X_test)
                Y_test = Y_test.squeeze(-1)
                test_loss = criterion(Y_pred_test, Y_test)

                LOSS_TRACE_FOR_TEST.append(LOSS_val.cpu().detach().numpy())

                Y_pred_test_np  = Y_pred_test.to('cpu').detach().numpy()
                Y_pred_test_np  = np.argmax(Y_pred_test_np, axis=1).reshape(-1, 1)
                Y_test_np       = Y_test.to('cpu').detach().numpy().reshape(-1, 1)
                
                Result_pred_test.append(list(Y_pred_test_np[0]))
                Result_anno_test.append(list(Y_test_np[0]))

            ACC_VAL        = metrics.accuracy_score(Result_anno_val, Result_pred_val)
            ACC_TEST       = metrics.accuracy_score(Result_anno_test, Result_pred_test)

            AVG_LOSS_TRAIN = np.average(LOSS_TRACE_FOR_TRAIN)
            AVG_LOSS_VAL   = np.average(LOSS_TRACE_FOR_VAL)
            AVG_LOSS_TEST  = np.average(LOSS_TRACE_FOR_TEST)

            LOSSES_TRAIN[model_idx].append(AVG_LOSS_TRAIN)
            LOSSES_VAL[model_idx].append(AVG_LOSS_VAL)
            LOSSES_TEST[model_idx].append(AVG_LOSS_TEST)
            ACCS_VAL[model_idx].append(ACC_VAL)
            ACCS_TEST[model_idx].append(ACC_TEST)
            print(f'(epoch {epoch + 1:03d}/{EPOCHS}) Training Loss : {AVG_LOSS_TRAIN:.5f} | Validation Loss : {AVG_LOSS_VAL:.5f} | Test Loss : {AVG_LOSS_TEST:.5f} | Validation Accuracy : {ACC_VAL*100:.2f} % | Test Accyracy : {ACC_TEST*100:.2f} %')
            
    end = time.time()
    print(f"Training took {end-start:.2f} sec")
# Out:
# EPOCHS:   0%|          | 0/50 [00:00<?, ?it/s]
# (epoch 001/50) Training Loss : 2.27265 | Validation Loss : 2.24083 | Test Loss : 2.23235 | Validation Accuracy : 6.67 % | Test Accyracy : 10.00 %
# (epoch 002/50) Training Loss : 2.22853 | Validation Loss : 2.21912 | Test Loss : 2.20991 | Validation Accuracy : 6.67 % | Test Accyracy : 10.00 %
# (epoch 003/50) Training Loss : 2.21506 | Validation Loss : 2.21080 | Test Loss : 2.20176 | Validation Accuracy : 20.00 % | Test Accyracy : 21.00 %
# (epoch 004/50) Training Loss : 2.20943 | Validation Loss : 2.20689 | Test Loss : 2.19783 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 005/50) Training Loss : 2.20653 | Validation Loss : 2.20478 | Test Loss : 2.19599 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 006/50) Training Loss : 2.20482 | Validation Loss : 2.20369 | Test Loss : 2.19448 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 007/50) Training Loss : 2.20368 | Validation Loss : 2.20241 | Test Loss : 2.19345 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 008/50) Training Loss : 2.20233 | Validation Loss : 2.20098 | Test Loss : 2.18983 | Validation Accuracy : 26.67 % | Test Accyracy : 23.00 %
# (epoch 009/50) Training Loss : 2.18775 | Validation Loss : 2.16933 | Test Loss : 2.16211 | Validation Accuracy : 21.67 % | Test Accyracy : 20.00 %
# (epoch 010/50) Training Loss : 2.15644 | Validation Loss : 2.14301 | Test Loss : 2.14196 | Validation Accuracy : 26.67 % | Test Accyracy : 19.00 %
# (epoch 011/50) Training Loss : 2.14027 | Validation Loss : 2.13521 | Test Loss : 2.13466 | Validation Accuracy : 25.00 % | Test Accyracy : 21.00 %
# (epoch 012/50) Training Loss : 2.13367 | Validation Loss : 2.12508 | Test Loss : 2.12027 | Validation Accuracy : 26.67 % | Test Accyracy : 23.00 %
# (epoch 013/50) Training Loss : 2.11441 | Validation Loss : 2.10111 | Test Loss : 2.08778 | Validation Accuracy : 21.67 % | Test Accyracy : 27.00 %
# (epoch 014/50) Training Loss : 2.09354 | Validation Loss : 2.08243 | Test Loss : 2.06173 | Validation Accuracy : 30.00 % | Test Accyracy : 36.00 %
# (epoch 015/50) Training Loss : 2.07722 | Validation Loss : 2.07150 | Test Loss : 2.04757 | Validation Accuracy : 36.67 % | Test Accyracy : 36.00 %
# (epoch 016/50) Training Loss : 2.07100 | Validation Loss : 2.06969 | Test Loss : 2.03774 | Validation Accuracy : 40.00 % | Test Accyracy : 35.00 %
# (epoch 017/50) Training Loss : 2.06402 | Validation Loss : 2.05274 | Test Loss : 2.04336 | Validation Accuracy : 26.67 % | Test Accyracy : 34.00 %
# (epoch 018/50) Training Loss : 2.03392 | Validation Loss : 2.01259 | Test Loss : 1.99715 | Validation Accuracy : 36.67 % | Test Accyracy : 42.00 %
# (epoch 019/50) Training Loss : 1.99732 | Validation Loss : 1.96581 | Test Loss : 2.00109 | Validation Accuracy : 43.33 % | Test Accyracy : 48.00 %
# (epoch 020/50) Training Loss : 1.95046 | Validation Loss : 1.92882 | Test Loss : 1.93726 | Validation Accuracy : 46.67 % | Test Accyracy : 47.00 %
# (epoch 021/50) Training Loss : 1.93170 | Validation Loss : 1.92085 | Test Loss : 1.96420 | Validation Accuracy : 46.67 % | Test Accyracy : 50.00 %
# (epoch 022/50) Training Loss : 1.91771 | Validation Loss : 1.91346 | Test Loss : 1.93451 | Validation Accuracy : 50.00 % | Test Accyracy : 49.00 %
# (epoch 023/50) Training Loss : 1.90407 | Validation Loss : 1.89343 | Test Loss : 1.91765 | Validation Accuracy : 53.33 % | Test Accyracy : 55.00 %
# (epoch 024/50) Training Loss : 1.88913 | Validation Loss : 1.87986 | Test Loss : 1.92473 | Validation Accuracy : 55.00 % | Test Accyracy : 56.00 %
# (epoch 025/50) Training Loss : 1.87026 | Validation Loss : 1.85632 | Test Loss : 1.87243 | Validation Accuracy : 56.67 % | Test Accyracy : 61.00 %
# (epoch 026/50) Training Loss : 1.85048 | Validation Loss : 1.84643 | Test Loss : 1.89814 | Validation Accuracy : 55.00 % | Test Accyracy : 65.00 %
# (epoch 027/50) Training Loss : 1.84114 | Validation Loss : 1.83956 | Test Loss : 1.87529 | Validation Accuracy : 53.33 % | Test Accyracy : 62.00 %
# (epoch 028/50) Training Loss : 1.83213 | Validation Loss : 1.82934 | Test Loss : 1.85786 | Validation Accuracy : 58.33 % | Test Accyracy : 59.00 %
# (epoch 029/50) Training Loss : 1.83353 | Validation Loss : 1.82908 | Test Loss : 1.85528 | Validation Accuracy : 55.00 % | Test Accyracy : 62.00 %
# (epoch 030/50) Training Loss : 1.82475 | Validation Loss : 1.82515 | Test Loss : 1.87091 | Validation Accuracy : 55.00 % | Test Accyracy : 65.00 %
# (epoch 031/50) Training Loss : 1.82055 | Validation Loss : 1.82391 | Test Loss : 1.87461 | Validation Accuracy : 56.67 % | Test Accyracy : 64.00 %
# (epoch 032/50) Training Loss : 1.81432 | Validation Loss : 1.81339 | Test Loss : 1.88403 | Validation Accuracy : 56.67 % | Test Accyracy : 65.00 %
# (epoch 033/50) Training Loss : 1.81386 | Validation Loss : 1.81497 | Test Loss : 1.88945 | Validation Accuracy : 53.33 % | Test Accyracy : 65.00 %
# (epoch 034/50) Training Loss : 1.81259 | Validation Loss : 1.80292 | Test Loss : 1.84144 | Validation Accuracy : 53.33 % | Test Accyracy : 64.00 %
# (epoch 035/50) Training Loss : 1.80775 | Validation Loss : 1.80037 | Test Loss : 1.86991 | Validation Accuracy : 61.67 % | Test Accyracy : 60.00 %
# (epoch 036/50) Training Loss : 1.79849 | Validation Loss : 1.80486 | Test Loss : 1.84952 | Validation Accuracy : 56.67 % | Test Accyracy : 63.00 %
# (epoch 037/50) Training Loss : 1.79797 | Validation Loss : 1.81387 | Test Loss : 1.85167 | Validation Accuracy : 58.33 % | Test Accyracy : 59.00 %
# (epoch 038/50) Training Loss : 1.80270 | Validation Loss : 1.80806 | Test Loss : 1.86075 | Validation Accuracy : 61.67 % | Test Accyracy : 64.00 %
# (epoch 039/50) Training Loss : 1.80016 | Validation Loss : 1.80380 | Test Loss : 1.85993 | Validation Accuracy : 58.33 % | Test Accyracy : 61.00 %
# (epoch 040/50) Training Loss : 1.80305 | Validation Loss : 1.79050 | Test Loss : 1.85051 | Validation Accuracy : 61.67 % | Test Accyracy : 68.00 %
# (epoch 041/50) Training Loss : 1.79415 | Validation Loss : 1.78217 | Test Loss : 1.87062 | Validation Accuracy : 61.67 % | Test Accyracy : 66.00 %
# (epoch 042/50) Training Loss : 1.78182 | Validation Loss : 1.78575 | Test Loss : 1.85074 | Validation Accuracy : 65.00 % | Test Accyracy : 65.00 %
# (epoch 043/50) Training Loss : 1.78226 | Validation Loss : 1.78409 | Test Loss : 1.83049 | Validation Accuracy : 60.00 % | Test Accyracy : 65.00 %
# (epoch 044/50) Training Loss : 1.79576 | Validation Loss : 1.80481 | Test Loss : 1.87214 | Validation Accuracy : 58.33 % | Test Accyracy : 59.00 %
# (epoch 045/50) Training Loss : 1.78520 | Validation Loss : 1.78183 | Test Loss : 1.81112 | Validation Accuracy : 60.00 % | Test Accyracy : 61.00 %
# (epoch 046/50) Training Loss : 1.78514 | Validation Loss : 1.78290 | Test Loss : 1.82377 | Validation Accuracy : 56.67 % | Test Accyracy : 62.00 %
# (epoch 047/50) Training Loss : 1.77522 | Validation Loss : 1.78795 | Test Loss : 1.84300 | Validation Accuracy : 58.33 % | Test Accyracy : 64.00 %
# (epoch 048/50) Training Loss : 1.78858 | Validation Loss : 1.80190 | Test Loss : 1.86992 | Validation Accuracy : 60.00 % | Test Accyracy : 62.00 %
# (epoch 049/50) Training Loss : 1.78589 | Validation Loss : 1.77361 | Test Loss : 1.82902 | Validation Accuracy : 61.67 % | Test Accyracy : 68.00 %
# (epoch 050/50) Training Loss : 1.76516 | Validation Loss : 1.77074 | Test Loss : 1.82481 | Validation Accuracy : 63.33 % | Test Accyracy : 66.00 %
# Training took 122.57 sec
# EPOCHS:   0%|          | 0/50 [00:00<?, ?it/s]
# (epoch 001/50) Training Loss : 2.28549 | Validation Loss : 2.25727 | Test Loss : 2.25007 | Validation Accuracy : 6.67 % | Test Accyracy : 10.00 %
# (epoch 002/50) Training Loss : 2.23695 | Validation Loss : 2.22217 | Test Loss : 2.21442 | Validation Accuracy : 6.67 % | Test Accyracy : 10.00 %
# (epoch 003/50) Training Loss : 2.21614 | Validation Loss : 2.21093 | Test Loss : 2.20344 | Validation Accuracy : 11.67 % | Test Accyracy : 13.00 %
# (epoch 004/50) Training Loss : 2.20897 | Validation Loss : 2.20654 | Test Loss : 2.19911 | Validation Accuracy : 20.00 % | Test Accyracy : 21.00 %
# (epoch 005/50) Training Loss : 2.20575 | Validation Loss : 2.20433 | Test Loss : 2.19698 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 006/50) Training Loss : 2.20404 | Validation Loss : 2.20310 | Test Loss : 2.19562 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 007/50) Training Loss : 2.20286 | Validation Loss : 2.20234 | Test Loss : 2.19461 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 008/50) Training Loss : 2.20219 | Validation Loss : 2.20181 | Test Loss : 2.19397 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 009/50) Training Loss : 2.20161 | Validation Loss : 2.20143 | Test Loss : 2.19350 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 010/50) Training Loss : 2.20116 | Validation Loss : 2.20107 | Test Loss : 2.19329 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 011/50) Training Loss : 2.20081 | Validation Loss : 2.20115 | Test Loss : 2.19299 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 012/50) Training Loss : 2.20068 | Validation Loss : 2.20093 | Test Loss : 2.19284 | Validation Accuracy : 20.00 % | Test Accyracy : 22.00 %
# (epoch 013/50) Training Loss : 2.20040 | Validation Loss : 2.20088 | Test Loss : 2.19259 | Validation Accuracy : 20.00 % | Test Accyracy : 21.00 %
# (epoch 014/50) Training Loss : 2.20008 | Validation Loss : 2.19977 | Test Loss : 2.19142 | Validation Accuracy : 21.67 % | Test Accyracy : 20.00 %
# (epoch 015/50) Training Loss : 2.16998 | Validation Loss : 2.13917 | Test Loss : 2.14400 | Validation Accuracy : 31.67 % | Test Accyracy : 30.00 %
# (epoch 016/50) Training Loss : 2.13019 | Validation Loss : 2.12428 | Test Loss : 2.12573 | Validation Accuracy : 31.67 % | Test Accyracy : 31.00 %
# (epoch 017/50) Training Loss : 2.11443 | Validation Loss : 2.09771 | Test Loss : 2.08595 | Validation Accuracy : 38.33 % | Test Accyracy : 36.00 %
# (epoch 018/50) Training Loss : 2.07453 | Validation Loss : 2.06198 | Test Loss : 2.04038 | Validation Accuracy : 38.33 % | Test Accyracy : 37.00 %
# (epoch 019/50) Training Loss : 2.05495 | Validation Loss : 2.05240 | Test Loss : 2.03033 | Validation Accuracy : 31.67 % | Test Accyracy : 33.00 %
# (epoch 020/50) Training Loss : 2.04802 | Validation Loss : 2.04872 | Test Loss : 2.02822 | Validation Accuracy : 33.33 % | Test Accyracy : 30.00 %
# (epoch 021/50) Training Loss : 2.04423 | Validation Loss : 2.04591 | Test Loss : 2.02342 | Validation Accuracy : 35.00 % | Test Accyracy : 31.00 %
# (epoch 022/50) Training Loss : 2.04183 | Validation Loss : 2.04469 | Test Loss : 2.02226 | Validation Accuracy : 41.67 % | Test Accyracy : 38.00 %
# (epoch 023/50) Training Loss : 2.04012 | Validation Loss : 2.04311 | Test Loss : 2.02288 | Validation Accuracy : 43.33 % | Test Accyracy : 38.00 %
# (epoch 024/50) Training Loss : 2.03872 | Validation Loss : 2.04223 | Test Loss : 2.02200 | Validation Accuracy : 41.67 % | Test Accyracy : 38.00 %
# (epoch 025/50) Training Loss : 2.03776 | Validation Loss : 2.04128 | Test Loss : 2.02053 | Validation Accuracy : 43.33 % | Test Accyracy : 38.00 %
# (epoch 026/50) Training Loss : 2.03673 | Validation Loss : 2.04119 | Test Loss : 2.02019 | Validation Accuracy : 43.33 % | Test Accyracy : 39.00 %
# (epoch 027/50) Training Loss : 2.03617 | Validation Loss : 2.04030 | Test Loss : 2.02044 | Validation Accuracy : 43.33 % | Test Accyracy : 38.00 %
# (epoch 028/50) Training Loss : 2.03541 | Validation Loss : 2.03963 | Test Loss : 2.01924 | Validation Accuracy : 43.33 % | Test Accyracy : 38.00 %
# (epoch 029/50) Training Loss : 2.03453 | Validation Loss : 2.03930 | Test Loss : 2.01886 | Validation Accuracy : 43.33 % | Test Accyracy : 41.00 %
# (epoch 030/50) Training Loss : 2.03377 | Validation Loss : 2.03849 | Test Loss : 2.01883 | Validation Accuracy : 43.33 % | Test Accyracy : 41.00 %
# (epoch 031/50) Training Loss : 2.03283 | Validation Loss : 2.03763 | Test Loss : 2.01796 | Validation Accuracy : 43.33 % | Test Accyracy : 38.00 %
# (epoch 032/50) Training Loss : 2.03077 | Validation Loss : 2.02901 | Test Loss : 2.00439 | Validation Accuracy : 41.67 % | Test Accyracy : 39.00 %
# (epoch 033/50) Training Loss : 2.00949 | Validation Loss : 2.00485 | Test Loss : 1.96013 | Validation Accuracy : 45.00 % | Test Accyracy : 43.00 %
# (epoch 034/50) Training Loss : 1.99298 | Validation Loss : 1.99073 | Test Loss : 1.94000 | Validation Accuracy : 46.67 % | Test Accyracy : 48.00 %
# (epoch 035/50) Training Loss : 1.98284 | Validation Loss : 1.98247 | Test Loss : 1.93244 | Validation Accuracy : 48.33 % | Test Accyracy : 49.00 %
# (epoch 036/50) Training Loss : 1.96803 | Validation Loss : 1.96011 | Test Loss : 1.93261 | Validation Accuracy : 51.67 % | Test Accyracy : 51.00 %
# (epoch 037/50) Training Loss : 1.94496 | Validation Loss : 1.94148 | Test Loss : 1.91970 | Validation Accuracy : 51.67 % | Test Accyracy : 55.00 %
# (epoch 038/50) Training Loss : 1.92545 | Validation Loss : 1.92192 | Test Loss : 1.91208 | Validation Accuracy : 58.33 % | Test Accyracy : 54.00 %
# (epoch 039/50) Training Loss : 1.89757 | Validation Loss : 1.89024 | Test Loss : 1.89271 | Validation Accuracy : 60.00 % | Test Accyracy : 60.00 %
# (epoch 040/50) Training Loss : 1.86270 | Validation Loss : 1.85815 | Test Loss : 1.86482 | Validation Accuracy : 58.33 % | Test Accyracy : 57.00 %
# (epoch 041/50) Training Loss : 1.83861 | Validation Loss : 1.83900 | Test Loss : 1.86741 | Validation Accuracy : 65.00 % | Test Accyracy : 62.00 %
# (epoch 042/50) Training Loss : 1.81668 | Validation Loss : 1.81450 | Test Loss : 1.84910 | Validation Accuracy : 71.67 % | Test Accyracy : 66.00 %
# (epoch 043/50) Training Loss : 1.79907 | Validation Loss : 1.80114 | Test Loss : 1.83838 | Validation Accuracy : 75.00 % | Test Accyracy : 73.00 %
# (epoch 044/50) Training Loss : 1.78694 | Validation Loss : 1.78861 | Test Loss : 1.82509 | Validation Accuracy : 75.00 % | Test Accyracy : 73.00 %
# (epoch 045/50) Training Loss : 1.77467 | Validation Loss : 1.77672 | Test Loss : 1.80265 | Validation Accuracy : 75.00 % | Test Accyracy : 74.00 %
# (epoch 046/50) Training Loss : 1.75994 | Validation Loss : 1.76105 | Test Loss : 1.78344 | Validation Accuracy : 80.00 % | Test Accyracy : 77.00 %
# (epoch 047/50) Training Loss : 1.73812 | Validation Loss : 1.71918 | Test Loss : 1.73736 | Validation Accuracy : 81.67 % | Test Accyracy : 81.00 %
# (epoch 048/50) Training Loss : 1.68709 | Validation Loss : 1.67785 | Test Loss : 1.69176 | Validation Accuracy : 83.33 % | Test Accyracy : 84.00 %
# (epoch 049/50) Training Loss : 1.65910 | Validation Loss : 1.65696 | Test Loss : 1.65980 | Validation Accuracy : 81.67 % | Test Accyracy : 82.00 %
# (epoch 050/50) Training Loss : 1.64352 | Validation Loss : 1.64269 | Test Loss : 1.64965 | Validation Accuracy : 80.00 % | Test Accyracy : 82.00 %
# Training took 116.89 sec

# %%
model_name = ['MLP_NoScale', 'MLP_Scale']
for i in range(len(models)):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('train and validation loss '+model_name[i])
    plt.plot(LOSSES_TRAIN[i], label = 'train')
    plt.plot(LOSSES_VAL[i], label = 'validation')
    plt.plot(LOSSES_TEST[i], label = 'test')
    plt.legend()
    plt.show()

# %%
for i in range(len(models)):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    #plt.ylim((0.7,1))
    plt.title('Accuracy '+model_name[i])
    plt.plot(ACCS_VAL[i], label = 'validation')
    plt.plot(ACCS_TEST[i], label = 'test')
    plt.legend()
plt.show()

# %%
# layers = ['layer1.0.weight']#, 'layer2.0.weight', 'layer3.0.weight']
# for i in range(2):
#     plt.ylim((0,0.001))
#     plt.xlabel('Iteration')
#     plt.ylabel('Magnitude')
#     plt.title('Sum of Magnitude of Gradient for each Iteration')#+model_name[i])
#     for layer, magnitudes in GRAD_MAG[i].items():
#         if layer in layers:
#             plt.plot(magnitudes, label = layer+' '+model_name[i])
#     plt.legend()
# plt.show()

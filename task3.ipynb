# %% [markdown]
# # IIE4123 HW2
# ## Kichang Lee(2019193016), School of Integrated Technology, Yonsei Univ
#
# Language : Python3(Python 3.9.7 64-bit)
#
# OS : Microsoft Windows 10 Education (10.0.19042)
#
# Environment
#
# CPU : Intel(R) Core(TM) i9-10850K CPU 3.60GHz, 3600Mhz, 10 Core with Intel(R) UHD Graphics 630
#
# RAM : 64GB
#
# GPU : RTX3090
#
# ## Notes about Task3
#
# I used a model with sigmoid function that I used in task2 but with out the batch normalization.
#
# (a) One with the preprocessing works better. In all the aspect of loss value and accuracy also the learning speed.
#
# (b) The rescaled data heps the model to learn better than one with the integer value. Preprocessing let the model to treat all the images in the same manner and let them contiributes more evenly to the total loss.

# %% [markdown]
# # Import Packages

# %%
import time

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Hyper-Parameters

# %%
BATCH_SIZE = 100
LEARNING_RATE = 0.001
EPOCHS = 50


USE_CUDA = torch.cuda.is_available() 
DEVICE = torch.device("cuda" if USE_CUDA else "cpu") 
print("다음 기기로 학습합니다:", DEVICE)
# Out:
# 다음 기기로 학습합니다: cuda

# %% [markdown]
# # Data Management

# %%
transform = transforms.Compose([transforms.ToTensor()]) # Rescaled into [0,1]

whole_train_set = dset.MNIST("./MNIST_data", train=True, transform=transform, download=False)
mnist_test = dset.MNIST("./MNIST_data", train=False, transform=transform, download=False)

mnist_train, mnist_val = train_test_split(whole_train_set, test_size = 0.1, stratify=whole_train_set.targets)

train_loader = torch.utils.data.DataLoader(mnist_train, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
val_loader = torch.utils.data.DataLoader(mnist_val, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)
test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)
# Out:
# C:\Users\Kichang\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torchvision\datasets\mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %% [markdown]
# # Model

# %%
class MLP(nn.Module):
    def __init__(self, activation_function):
        super(MLP, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Linear(784, 15, bias=True),
            activation_function
        )
        self.layer2 = nn.Sequential(
            nn.Linear(15, 12, bias=True),
            activation_function
        )
        self.layer3 = nn.Sequential(
            nn.Linear(12, 12, bias=True),
            activation_function
        )
        self.layer4 = nn.Sequential(
            nn.Linear(12, 10, bias=True),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        x = x.view(x.size(0), -1) # flatten
        x_out = self.layer1(x)
        x_out = self.layer2(x_out)
        x_out = self.layer3(x_out)        
        x_out = self.layer4(x_out)
        return x_out
        
def weights_init(m):
    if isinstance(m, nn.Linear):
        nn.init.normal_(m.weight)
        nn.init.constant_(m.bias, 0)

# %%
models = [ MLP(nn.Sigmoid()).apply(weights_init).to(DEVICE), MLP(nn.Sigmoid()).apply(weights_init).to(DEVICE) ]#MLP(nn.ReLU()).apply(weights_init).to(DEVICE), MLP(nn.Sigmoid()).apply(weights_init).to(DEVICE)]
criterion = nn.CrossEntropyLoss().to(DEVICE)

# %%
LOSSES_TRAIN, LOSSES_VAL, LOSSES_TEST = [[] for idx in range(len(models))], [[] for idx in range(len(models))], [[] for idx in range(len(models))]
ACCS_VAL, ACCS_TEST = [[] for idx in range(len(models))], [[] for idx in range(len(models))]

GRAD_MAG = [[] for idx in range(len(models))]

for model_idx, model in enumerate(models):
    dict_param = dict()
    for name, params in model.named_parameters():
        dict_param[name] = []
    GRAD_MAG[model_idx] = dict_param

# %%
for model_idx, model in enumerate(models):
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    train_sample_num = len(train_loader)
    val_sample_num = len(val_loader)

    start = time.time()
    for epoch in tqdm(range(EPOCHS), desc="EPOCHS"):
        model.train()
        LOSS_TRACE_FOR_TRAIN, LOSS_TRACE_FOR_VAL, LOSS_TRACE_FOR_TEST = [], [], []
        for idx, batch in enumerate(train_loader):
            optimizer.zero_grad()
            
            if model_idx == 0:
                X_train, Y_train = batch[0]*255, batch[1]
            else:
                X_train, Y_train = batch
            X_train, Y_train = X_train.to(DEVICE), Y_train.to(DEVICE)

            Y_pred_train = model(X_train)
            Y_train = Y_train.squeeze(-1)

            LOSS_train = criterion(Y_pred_train, Y_train)

            LOSS_TRACE_FOR_TRAIN.append(LOSS_train.cpu().detach().numpy())
            LOSS_train.backward()
            optimizer.step()
            # for name, params in model.named_parameters():
            #     if type(params.grad) != None:
            #         GRAD_MAG[model_idx][name].append(((sum(sum((params.grad**2)**0.5))/params.numel()).cpu().detach().numpy() if len(params.size()) == 2 else (sum((params.grad**2)**0.5)/params.numel()).cpu().detach().numpy()))
            # #print(name, '\n', (sum(sum((params.grad**2)**0.5))/params.numel() if len(params.size()) == 2 else sum((params.grad**2)**0.5)/params.numel()), '\n')

        with torch.no_grad():
            model.eval()

            Result_pred_val, Result_anno_val = [], []
            for idx, batch in enumerate(val_loader):
                if model_idx == 0:
                    X_val, Y_val = batch[0]*255, batch[1]
                else:
                    X_val, Y_val = batch
                X_val, Y_val = X_val.to(DEVICE), Y_val.to(DEVICE)

                Y_pred_val = model(X_val)
                Y_val = Y_val.squeeze(-1)
                LOSS_val = criterion(Y_pred_val, Y_val)

                LOSS_TRACE_FOR_VAL.append(LOSS_val.cpu().detach().numpy())

                Y_pred_val_np  = Y_pred_val.to('cpu').detach().numpy()
                Y_pred_val_np  = np.argmax(Y_pred_val_np, axis=1).reshape(-1, 1)
                Y_val_np       = Y_val.to('cpu').detach().numpy().reshape(-1, 1)

                Result_pred_val.append(list(Y_pred_val_np[0]))
                Result_anno_val.append(list(Y_val_np[0]))
            
            Result_pred_test, Result_anno_test = [], []
            for idx, batch in enumerate(test_loader):
                if model_idx == 0:
                    X_test, Y_test = batch[0]*255, batch[1]
                else:
                    X_test, Y_test = batch
                X_test, Y_test = X_test.to(DEVICE), Y_test.to(DEVICE)

                Y_pred_test = model(X_test)
                Y_test = Y_test.squeeze(-1)
                test_loss = criterion(Y_pred_test, Y_test)

                LOSS_TRACE_FOR_TEST.append(LOSS_val.cpu().detach().numpy())

                Y_pred_test_np  = Y_pred_test.to('cpu').detach().numpy()
                Y_pred_test_np  = np.argmax(Y_pred_test_np, axis=1).reshape(-1, 1)
                Y_test_np       = Y_test.to('cpu').detach().numpy().reshape(-1, 1)
                
                Result_pred_test.append(list(Y_pred_test_np[0]))
                Result_anno_test.append(list(Y_test_np[0]))

            ACC_VAL        = metrics.accuracy_score(Result_anno_val, Result_pred_val)
            ACC_TEST       = metrics.accuracy_score(Result_anno_test, Result_pred_test)

            AVG_LOSS_TRAIN = np.average(LOSS_TRACE_FOR_TRAIN)
            AVG_LOSS_VAL   = np.average(LOSS_TRACE_FOR_VAL)
            AVG_LOSS_TEST  = np.average(LOSS_TRACE_FOR_TEST)

            LOSSES_TRAIN[model_idx].append(AVG_LOSS_TRAIN)
            LOSSES_VAL[model_idx].append(AVG_LOSS_VAL)
            LOSSES_TEST[model_idx].append(AVG_LOSS_TEST)
            ACCS_VAL[model_idx].append(ACC_VAL)
            ACCS_TEST[model_idx].append(ACC_TEST)
            print(f'(epoch {epoch + 1:03d}/{EPOCHS}) Training Loss : {AVG_LOSS_TRAIN:.5f} | Validation Loss : {AVG_LOSS_VAL:.5f} | Test Loss : {AVG_LOSS_TEST:.5f} | Validation Accuracy : {ACC_VAL*100:.2f} % | Test Accyracy : {ACC_TEST*100:.2f} %')
            
    end = time.time()
    print(f"Training took {end-start:.2f} sec")
# Out:
# EPOCHS:   0%|          | 0/50 [00:00<?, ?it/s]
# (epoch 001/50) Training Loss : 2.25496 | Validation Loss : 2.20929 | Test Loss : 2.20517 | Validation Accuracy : 40.00 % | Test Accyracy : 30.00 %
# (epoch 002/50) Training Loss : 2.14554 | Validation Loss : 2.09222 | Test Loss : 2.10065 | Validation Accuracy : 50.00 % | Test Accyracy : 37.00 %
# (epoch 003/50) Training Loss : 2.05952 | Validation Loss : 2.03161 | Test Loss : 2.08662 | Validation Accuracy : 53.33 % | Test Accyracy : 43.00 %
# (epoch 004/50) Training Loss : 2.01384 | Validation Loss : 1.99858 | Test Loss : 2.05815 | Validation Accuracy : 56.67 % | Test Accyracy : 47.00 %
# (epoch 005/50) Training Loss : 1.98148 | Validation Loss : 1.96759 | Test Loss : 2.03641 | Validation Accuracy : 60.00 % | Test Accyracy : 43.00 %
# (epoch 006/50) Training Loss : 1.94832 | Validation Loss : 1.93781 | Test Loss : 2.01956 | Validation Accuracy : 60.00 % | Test Accyracy : 51.00 %
# (epoch 007/50) Training Loss : 1.92736 | Validation Loss : 1.91772 | Test Loss : 1.96535 | Validation Accuracy : 66.67 % | Test Accyracy : 53.00 %
# (epoch 008/50) Training Loss : 1.90873 | Validation Loss : 1.90295 | Test Loss : 1.94042 | Validation Accuracy : 68.33 % | Test Accyracy : 53.00 %
# (epoch 009/50) Training Loss : 1.90064 | Validation Loss : 1.89172 | Test Loss : 1.94296 | Validation Accuracy : 70.00 % | Test Accyracy : 56.00 %
# (epoch 010/50) Training Loss : 1.89480 | Validation Loss : 1.89014 | Test Loss : 1.92989 | Validation Accuracy : 65.00 % | Test Accyracy : 55.00 %
# (epoch 011/50) Training Loss : 1.88618 | Validation Loss : 1.87980 | Test Loss : 1.92022 | Validation Accuracy : 61.67 % | Test Accyracy : 54.00 %
# (epoch 012/50) Training Loss : 1.87275 | Validation Loss : 1.86171 | Test Loss : 1.91813 | Validation Accuracy : 70.00 % | Test Accyracy : 54.00 %
# (epoch 013/50) Training Loss : 1.86136 | Validation Loss : 1.85388 | Test Loss : 1.89418 | Validation Accuracy : 66.67 % | Test Accyracy : 59.00 %
# (epoch 014/50) Training Loss : 1.85126 | Validation Loss : 1.84532 | Test Loss : 1.89063 | Validation Accuracy : 70.00 % | Test Accyracy : 62.00 %
# (epoch 015/50) Training Loss : 1.84219 | Validation Loss : 1.83780 | Test Loss : 1.88078 | Validation Accuracy : 65.00 % | Test Accyracy : 62.00 %
# (epoch 016/50) Training Loss : 1.83650 | Validation Loss : 1.83573 | Test Loss : 1.87891 | Validation Accuracy : 70.00 % | Test Accyracy : 62.00 %
# (epoch 017/50) Training Loss : 1.82842 | Validation Loss : 1.82356 | Test Loss : 1.84808 | Validation Accuracy : 70.00 % | Test Accyracy : 62.00 %
# (epoch 018/50) Training Loss : 1.82356 | Validation Loss : 1.82018 | Test Loss : 1.85909 | Validation Accuracy : 70.00 % | Test Accyracy : 59.00 %
# (epoch 019/50) Training Loss : 1.81688 | Validation Loss : 1.81669 | Test Loss : 1.84108 | Validation Accuracy : 73.33 % | Test Accyracy : 67.00 %
# (epoch 020/50) Training Loss : 1.81070 | Validation Loss : 1.80868 | Test Loss : 1.84441 | Validation Accuracy : 70.00 % | Test Accyracy : 69.00 %
# (epoch 021/50) Training Loss : 1.80390 | Validation Loss : 1.80614 | Test Loss : 1.87840 | Validation Accuracy : 70.00 % | Test Accyracy : 66.00 %
# (epoch 022/50) Training Loss : 1.79721 | Validation Loss : 1.79985 | Test Loss : 1.88140 | Validation Accuracy : 73.33 % | Test Accyracy : 71.00 %
# (epoch 023/50) Training Loss : 1.79237 | Validation Loss : 1.79164 | Test Loss : 1.87843 | Validation Accuracy : 73.33 % | Test Accyracy : 71.00 %
# (epoch 024/50) Training Loss : 1.78893 | Validation Loss : 1.79335 | Test Loss : 1.85958 | Validation Accuracy : 78.33 % | Test Accyracy : 69.00 %
# (epoch 025/50) Training Loss : 1.78706 | Validation Loss : 1.79070 | Test Loss : 1.82919 | Validation Accuracy : 78.33 % | Test Accyracy : 70.00 %
# (epoch 026/50) Training Loss : 1.78478 | Validation Loss : 1.78292 | Test Loss : 1.82625 | Validation Accuracy : 75.00 % | Test Accyracy : 71.00 %
# (epoch 027/50) Training Loss : 1.78245 | Validation Loss : 1.77829 | Test Loss : 1.82223 | Validation Accuracy : 76.67 % | Test Accyracy : 74.00 %
# (epoch 028/50) Training Loss : 1.77664 | Validation Loss : 1.77949 | Test Loss : 1.83786 | Validation Accuracy : 76.67 % | Test Accyracy : 73.00 %
# (epoch 029/50) Training Loss : 1.77347 | Validation Loss : 1.77413 | Test Loss : 1.83841 | Validation Accuracy : 80.00 % | Test Accyracy : 70.00 %
# (epoch 030/50) Training Loss : 1.76976 | Validation Loss : 1.76842 | Test Loss : 1.82313 | Validation Accuracy : 75.00 % | Test Accyracy : 73.00 %
# (epoch 031/50) Training Loss : 1.76427 | Validation Loss : 1.76475 | Test Loss : 1.82752 | Validation Accuracy : 76.67 % | Test Accyracy : 74.00 %
# (epoch 032/50) Training Loss : 1.76340 | Validation Loss : 1.76189 | Test Loss : 1.80336 | Validation Accuracy : 80.00 % | Test Accyracy : 71.00 %
# (epoch 033/50) Training Loss : 1.75960 | Validation Loss : 1.76184 | Test Loss : 1.81938 | Validation Accuracy : 76.67 % | Test Accyracy : 71.00 %
# (epoch 034/50) Training Loss : 1.76008 | Validation Loss : 1.76304 | Test Loss : 1.84761 | Validation Accuracy : 78.33 % | Test Accyracy : 71.00 %
# (epoch 035/50) Training Loss : 1.75703 | Validation Loss : 1.75838 | Test Loss : 1.81025 | Validation Accuracy : 76.67 % | Test Accyracy : 72.00 %
# (epoch 036/50) Training Loss : 1.75541 | Validation Loss : 1.75537 | Test Loss : 1.80980 | Validation Accuracy : 76.67 % | Test Accyracy : 73.00 %
# (epoch 037/50) Training Loss : 1.75353 | Validation Loss : 1.75120 | Test Loss : 1.79801 | Validation Accuracy : 76.67 % | Test Accyracy : 74.00 %
# (epoch 038/50) Training Loss : 1.75251 | Validation Loss : 1.74851 | Test Loss : 1.79300 | Validation Accuracy : 78.33 % | Test Accyracy : 71.00 %
# (epoch 039/50) Training Loss : 1.75095 | Validation Loss : 1.74748 | Test Loss : 1.81275 | Validation Accuracy : 75.00 % | Test Accyracy : 71.00 %
# (epoch 040/50) Training Loss : 1.74848 | Validation Loss : 1.74423 | Test Loss : 1.79661 | Validation Accuracy : 73.33 % | Test Accyracy : 74.00 %
# (epoch 041/50) Training Loss : 1.74290 | Validation Loss : 1.74114 | Test Loss : 1.80007 | Validation Accuracy : 75.00 % | Test Accyracy : 72.00 %
# (epoch 042/50) Training Loss : 1.74044 | Validation Loss : 1.74079 | Test Loss : 1.79687 | Validation Accuracy : 73.33 % | Test Accyracy : 74.00 %
# (epoch 043/50) Training Loss : 1.73943 | Validation Loss : 1.74162 | Test Loss : 1.79036 | Validation Accuracy : 76.67 % | Test Accyracy : 74.00 %
# (epoch 044/50) Training Loss : 1.74155 | Validation Loss : 1.73868 | Test Loss : 1.79865 | Validation Accuracy : 76.67 % | Test Accyracy : 73.00 %
# (epoch 045/50) Training Loss : 1.73677 | Validation Loss : 1.73359 | Test Loss : 1.77549 | Validation Accuracy : 76.67 % | Test Accyracy : 74.00 %
# (epoch 046/50) Training Loss : 1.73527 | Validation Loss : 1.73741 | Test Loss : 1.78057 | Validation Accuracy : 78.33 % | Test Accyracy : 74.00 %
# (epoch 047/50) Training Loss : 1.73454 | Validation Loss : 1.73342 | Test Loss : 1.78939 | Validation Accuracy : 80.00 % | Test Accyracy : 73.00 %
# (epoch 048/50) Training Loss : 1.73335 | Validation Loss : 1.73331 | Test Loss : 1.80100 | Validation Accuracy : 80.00 % | Test Accyracy : 75.00 %
# (epoch 049/50) Training Loss : 1.73324 | Validation Loss : 1.73722 | Test Loss : 1.77977 | Validation Accuracy : 80.00 % | Test Accyracy : 72.00 %
# (epoch 050/50) Training Loss : 1.73019 | Validation Loss : 1.73082 | Test Loss : 1.75870 | Validation Accuracy : 78.33 % | Test Accyracy : 73.00 %
# Training took 103.08 sec
# EPOCHS:   0%|          | 0/50 [00:00<?, ?it/s]
# (epoch 001/50) Training Loss : 2.23986 | Validation Loss : 2.14505 | Test Loss : 2.16183 | Validation Accuracy : 36.67 % | Test Accyracy : 32.00 %
# (epoch 002/50) Training Loss : 2.08095 | Validation Loss : 2.02079 | Test Loss : 2.01641 | Validation Accuracy : 56.67 % | Test Accyracy : 44.00 %
# (epoch 003/50) Training Loss : 1.94897 | Validation Loss : 1.89039 | Test Loss : 1.87917 | Validation Accuracy : 75.00 % | Test Accyracy : 59.00 %
# (epoch 004/50) Training Loss : 1.86220 | Validation Loss : 1.85186 | Test Loss : 1.82504 | Validation Accuracy : 76.67 % | Test Accyracy : 61.00 %
# (epoch 005/50) Training Loss : 1.83823 | Validation Loss : 1.83601 | Test Loss : 1.79105 | Validation Accuracy : 76.67 % | Test Accyracy : 60.00 %
# (epoch 006/50) Training Loss : 1.81766 | Validation Loss : 1.80101 | Test Loss : 1.79958 | Validation Accuracy : 83.33 % | Test Accyracy : 67.00 %
# (epoch 007/50) Training Loss : 1.78174 | Validation Loss : 1.77582 | Test Loss : 1.77588 | Validation Accuracy : 83.33 % | Test Accyracy : 68.00 %
# (epoch 008/50) Training Loss : 1.76444 | Validation Loss : 1.76472 | Test Loss : 1.76883 | Validation Accuracy : 85.00 % | Test Accyracy : 68.00 %
# (epoch 009/50) Training Loss : 1.75471 | Validation Loss : 1.75668 | Test Loss : 1.75038 | Validation Accuracy : 85.00 % | Test Accyracy : 68.00 %
# (epoch 010/50) Training Loss : 1.74780 | Validation Loss : 1.75095 | Test Loss : 1.75698 | Validation Accuracy : 86.67 % | Test Accyracy : 68.00 %
# (epoch 011/50) Training Loss : 1.68580 | Validation Loss : 1.66600 | Test Loss : 1.68961 | Validation Accuracy : 91.67 % | Test Accyracy : 77.00 %
# (epoch 012/50) Training Loss : 1.65286 | Validation Loss : 1.65400 | Test Loss : 1.67708 | Validation Accuracy : 90.00 % | Test Accyracy : 77.00 %
# (epoch 013/50) Training Loss : 1.64441 | Validation Loss : 1.64803 | Test Loss : 1.66979 | Validation Accuracy : 90.00 % | Test Accyracy : 77.00 %
# (epoch 014/50) Training Loss : 1.63899 | Validation Loss : 1.64359 | Test Loss : 1.66373 | Validation Accuracy : 90.00 % | Test Accyracy : 77.00 %
# (epoch 015/50) Training Loss : 1.63480 | Validation Loss : 1.64125 | Test Loss : 1.67227 | Validation Accuracy : 90.00 % | Test Accyracy : 77.00 %
# (epoch 016/50) Training Loss : 1.63152 | Validation Loss : 1.63869 | Test Loss : 1.66678 | Validation Accuracy : 91.67 % | Test Accyracy : 77.00 %
# (epoch 017/50) Training Loss : 1.62906 | Validation Loss : 1.63656 | Test Loss : 1.65868 | Validation Accuracy : 91.67 % | Test Accyracy : 77.00 %
# (epoch 018/50) Training Loss : 1.62685 | Validation Loss : 1.63524 | Test Loss : 1.66245 | Validation Accuracy : 90.00 % | Test Accyracy : 77.00 %
# (epoch 019/50) Training Loss : 1.62480 | Validation Loss : 1.63418 | Test Loss : 1.65605 | Validation Accuracy : 91.67 % | Test Accyracy : 78.00 %
# (epoch 020/50) Training Loss : 1.62280 | Validation Loss : 1.63294 | Test Loss : 1.65987 | Validation Accuracy : 91.67 % | Test Accyracy : 77.00 %
# (epoch 021/50) Training Loss : 1.62131 | Validation Loss : 1.63251 | Test Loss : 1.65285 | Validation Accuracy : 90.00 % | Test Accyracy : 79.00 %
# (epoch 022/50) Training Loss : 1.60148 | Validation Loss : 1.58965 | Test Loss : 1.63395 | Validation Accuracy : 86.67 % | Test Accyracy : 85.00 %
# (epoch 023/50) Training Loss : 1.57025 | Validation Loss : 1.57647 | Test Loss : 1.61317 | Validation Accuracy : 88.33 % | Test Accyracy : 86.00 %
# (epoch 024/50) Training Loss : 1.56071 | Validation Loss : 1.56927 | Test Loss : 1.60232 | Validation Accuracy : 88.33 % | Test Accyracy : 86.00 %
# (epoch 025/50) Training Loss : 1.55493 | Validation Loss : 1.56540 | Test Loss : 1.59158 | Validation Accuracy : 90.00 % | Test Accyracy : 86.00 %
# (epoch 026/50) Training Loss : 1.55087 | Validation Loss : 1.56238 | Test Loss : 1.59379 | Validation Accuracy : 90.00 % | Test Accyracy : 86.00 %
# (epoch 027/50) Training Loss : 1.54748 | Validation Loss : 1.56055 | Test Loss : 1.59061 | Validation Accuracy : 90.00 % | Test Accyracy : 88.00 %
# (epoch 028/50) Training Loss : 1.54482 | Validation Loss : 1.55853 | Test Loss : 1.58400 | Validation Accuracy : 90.00 % | Test Accyracy : 88.00 %
# (epoch 029/50) Training Loss : 1.54261 | Validation Loss : 1.55699 | Test Loss : 1.58375 | Validation Accuracy : 90.00 % | Test Accyracy : 88.00 %
# (epoch 030/50) Training Loss : 1.54071 | Validation Loss : 1.55564 | Test Loss : 1.56889 | Validation Accuracy : 90.00 % | Test Accyracy : 88.00 %
# (epoch 031/50) Training Loss : 1.53910 | Validation Loss : 1.55318 | Test Loss : 1.56767 | Validation Accuracy : 91.67 % | Test Accyracy : 89.00 %
# (epoch 032/50) Training Loss : 1.53753 | Validation Loss : 1.55277 | Test Loss : 1.57087 | Validation Accuracy : 91.67 % | Test Accyracy : 89.00 %
# (epoch 033/50) Training Loss : 1.53600 | Validation Loss : 1.55270 | Test Loss : 1.57552 | Validation Accuracy : 90.00 % | Test Accyracy : 88.00 %
# (epoch 034/50) Training Loss : 1.53473 | Validation Loss : 1.55082 | Test Loss : 1.57407 | Validation Accuracy : 90.00 % | Test Accyracy : 90.00 %
# (epoch 035/50) Training Loss : 1.53344 | Validation Loss : 1.55023 | Test Loss : 1.57267 | Validation Accuracy : 90.00 % | Test Accyracy : 89.00 %
# (epoch 036/50) Training Loss : 1.53237 | Validation Loss : 1.54948 | Test Loss : 1.57605 | Validation Accuracy : 90.00 % | Test Accyracy : 88.00 %
# (epoch 037/50) Training Loss : 1.53114 | Validation Loss : 1.54847 | Test Loss : 1.57392 | Validation Accuracy : 90.00 % | Test Accyracy : 89.00 %
# (epoch 038/50) Training Loss : 1.53002 | Validation Loss : 1.54833 | Test Loss : 1.56631 | Validation Accuracy : 90.00 % | Test Accyracy : 90.00 %
# (epoch 039/50) Training Loss : 1.52921 | Validation Loss : 1.54756 | Test Loss : 1.57008 | Validation Accuracy : 91.67 % | Test Accyracy : 88.00 %
# (epoch 040/50) Training Loss : 1.52826 | Validation Loss : 1.54697 | Test Loss : 1.57243 | Validation Accuracy : 90.00 % | Test Accyracy : 88.00 %
# (epoch 041/50) Training Loss : 1.52737 | Validation Loss : 1.54720 | Test Loss : 1.57308 | Validation Accuracy : 90.00 % | Test Accyracy : 88.00 %
# (epoch 042/50) Training Loss : 1.52639 | Validation Loss : 1.54625 | Test Loss : 1.56895 | Validation Accuracy : 90.00 % | Test Accyracy : 89.00 %
# (epoch 043/50) Training Loss : 1.52567 | Validation Loss : 1.54578 | Test Loss : 1.57330 | Validation Accuracy : 90.00 % | Test Accyracy : 89.00 %
# (epoch 044/50) Training Loss : 1.52495 | Validation Loss : 1.54521 | Test Loss : 1.56610 | Validation Accuracy : 90.00 % | Test Accyracy : 89.00 %
# (epoch 045/50) Training Loss : 1.52417 | Validation Loss : 1.54528 | Test Loss : 1.56823 | Validation Accuracy : 91.67 % | Test Accyracy : 89.00 %
# (epoch 046/50) Training Loss : 1.52351 | Validation Loss : 1.54413 | Test Loss : 1.56404 | Validation Accuracy : 91.67 % | Test Accyracy : 89.00 %
# (epoch 047/50) Training Loss : 1.52258 | Validation Loss : 1.54438 | Test Loss : 1.55892 | Validation Accuracy : 91.67 % | Test Accyracy : 89.00 %
# (epoch 048/50) Training Loss : 1.52209 | Validation Loss : 1.54386 | Test Loss : 1.55940 | Validation Accuracy : 91.67 % | Test Accyracy : 89.00 %
# (epoch 049/50) Training Loss : 1.52142 | Validation Loss : 1.54426 | Test Loss : 1.56017 | Validation Accuracy : 91.67 % | Test Accyracy : 88.00 %
# (epoch 050/50) Training Loss : 1.52090 | Validation Loss : 1.54319 | Test Loss : 1.55863 | Validation Accuracy : 91.67 % | Test Accyracy : 89.00 %
# Training took 96.38 sec

# %%
model_name = ['MLP_NoScale', 'MLP_Scale']
for i in range(len(models)):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('train and validation loss '+model_name[i])
    plt.plot(LOSSES_TRAIN[i], label = 'train')
    plt.plot(LOSSES_VAL[i], label = 'validation')
    plt.plot(LOSSES_TEST[i], label = 'test')
    plt.legend()
    plt.show()

# %%
for i in range(len(models)):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    #plt.ylim((0.7,1))
    plt.title('Accuracy '+model_name[i])
    plt.plot(ACCS_VAL[i], label = 'validation')
    plt.plot(ACCS_TEST[i], label = 'test')
    plt.legend()
plt.show()

# %%
# layers = ['layer1.0.weight']#, 'layer2.0.weight', 'layer3.0.weight']
# for i in range(2):
#     plt.ylim((0,0.001))
#     plt.xlabel('Iteration')
#     plt.ylabel('Magnitude')
#     plt.title('Sum of Magnitude of Gradient for each Iteration')#+model_name[i])
#     for layer, magnitudes in GRAD_MAG[i].items():
#         if layer in layers:
#             plt.plot(magnitudes, label = layer+' '+model_name[i])
#     plt.legend()
# plt.show()

# %% [markdown]
# # IIE4123 HW2
# ## Kichang Lee(2019193016), School of Integrated Technology, Yonsei Univ
#
# Language : Python3(Python 3.9.7 64-bit)
#
# OS : Microsoft Windows 10 Education (10.0.19042)
#
# Environment
#
# CPU : Intel(R) Core(TM) i9-10850K CPU 3.60GHz, 3600Mhz, 10 Core with Intel(R) UHD Graphics 630
#
# RAM : 64GB
#
# GPU : RTX3090
#
# ## Notes about Task2
#
# I don't really know the criteria of vanishing gradient, both models with each activation function showed enough performance.
# I traced the average value of gradient of weight for every iterations, You can see that the values of the model with ReLU showed greater than the one with sigmoid.
#
# (a) both of them worked pretty well, the model with sigmoid's learning curve clearly shows that The optimizer intervened in the learning process. And I'm guessing that the vanishing gradient problem slowed down the model's learning speed.
#
#
# (b) ReLU applied model showed slightly better performance. We can guess that is maybe because of the vanishing gradient problem.

# %% [markdown]
# # Import Packages

# %%
import time

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.init as init
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Hyper-Parameters

# %%
BATCH_SIZE = 100
LEARNING_RATE = 0.001
EPOCHS = 50


USE_CUDA = torch.cuda.is_available() 
DEVICE = torch.device("cuda" if USE_CUDA else "cpu") 
print("다음 기기로 학습합니다:", DEVICE)
# Out:
# 다음 기기로 학습합니다: cuda

# %% [markdown]
# # Data Management

# %%
transform = transforms.Compose([transforms.ToTensor()]) # Rescaled into [0,1]

whole_train_set = dset.MNIST("./MNIST_data", train=True, transform=transform, download=False)
mnist_test = dset.MNIST("./MNIST_data", train=False, transform=transform, download=False)

mnist_train, mnist_val = train_test_split(whole_train_set, test_size = 0.1, stratify=whole_train_set.targets)

train_loader = torch.utils.data.DataLoader(mnist_train, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
val_loader = torch.utils.data.DataLoader(mnist_val, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)
test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)
# Out:
# C:\Users\Kichang\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\torchvision\datasets\mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  ..\torch\csrc\utils\tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %% [markdown]
# # Model

# %%
class MLP(nn.Module):
    def __init__(self, activation_function):
        super(MLP, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Linear(784, 15, bias=True),
            activation_function
        )
        self.layer2 = nn.Sequential(
            nn.Linear(15, 12, bias=True),
            activation_function
        )
        self.layer3 = nn.Sequential(
            nn.Linear(12, 12, bias=True),
            activation_function
        )
        self.layer4 = nn.Sequential(
            nn.Linear(12, 10, bias=True),
            nn.Softmax(dim=1)
        )

    def forward(self, x):
        x = x.view(x.size(0), -1) # flatten
        x_out = self.layer1(x)
        x_out = self.layer2(x_out)
        x_out = self.layer3(x_out)        
        x_out = self.layer4(x_out)
        return x_out
        
def weights_init(m):
    if isinstance(m, nn.Linear):
        nn.init.normal_(m.weight, mean=0.0, std=0.01)
        nn.init.constant_(m.bias, 0)

# %%
models = [ MLP(nn.ReLU()).apply(weights_init).to(DEVICE), MLP(nn.Sigmoid()).apply(weights_init).to(DEVICE)]
criterion = nn.CrossEntropyLoss().to(DEVICE)

# %%
LOSSES_TRAIN, LOSSES_VAL, LOSSES_TEST = [[] for idx in range(len(models))], [[] for idx in range(len(models))], [[] for idx in range(len(models))]
ACCS_VAL, ACCS_TEST = [[] for idx in range(len(models))], [[] for idx in range(len(models))]

GRAD_MAG = [[] for idx in range(len(models))]

for model_idx, model in enumerate(models):
    dict_param = dict()
    for name, params in model.named_parameters():
        dict_param[name] = []
    GRAD_MAG[model_idx] = dict_param

# %%
for model_idx, model in enumerate(models):
    optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)
    train_sample_num = len(train_loader)
    val_sample_num = len(val_loader)

    start = time.time()
    for epoch in tqdm(range(EPOCHS), desc="EPOCHS"):
        model.train()
        LOSS_TRACE_FOR_TRAIN, LOSS_TRACE_FOR_VAL, LOSS_TRACE_FOR_TEST = [], [], []
        for idx, batch in enumerate(train_loader):
            optimizer.zero_grad()

            X_train, Y_train = batch
            X_train, Y_train = X_train.to(DEVICE), Y_train.to(DEVICE)

            Y_pred_train = model(X_train)
            Y_train = Y_train.squeeze(-1)

            LOSS_train = criterion(Y_pred_train, Y_train)

            LOSS_TRACE_FOR_TRAIN.append(LOSS_train.cpu().detach().numpy())
            LOSS_train.backward()
            optimizer.step()
            for name, params in model.named_parameters():
                if type(params.grad) != None:
                    GRAD_MAG[model_idx][name].append(((sum(sum((params.grad**2)**0.5))/params.numel()).cpu().detach().numpy() if len(params.size()) == 2 else (sum((params.grad**2)**0.5)/params.numel()).cpu().detach().numpy()))
            #print(name, '\n', (sum(sum((params.grad**2)**0.5))/params.numel() if len(params.size()) == 2 else sum((params.grad**2)**0.5)/params.numel()), '\n')

        with torch.no_grad():
            model.eval()

            Result_pred_val, Result_anno_val = [], []
            for idx, batch in enumerate(val_loader):
                X_val, Y_val = batch
                X_val, Y_val = X_val.to(DEVICE), Y_val.to(DEVICE)

                Y_pred_val = model(X_val)
                Y_val = Y_val.squeeze(-1)
                LOSS_val = criterion(Y_pred_val, Y_val)

                LOSS_TRACE_FOR_VAL.append(LOSS_val.cpu().detach().numpy())

                Y_pred_val_np  = Y_pred_val.to('cpu').detach().numpy()
                Y_pred_val_np  = np.argmax(Y_pred_val_np, axis=1).reshape(-1, 1)
                Y_val_np       = Y_val.to('cpu').detach().numpy().reshape(-1, 1)

                Result_pred_val.append(list(Y_pred_val_np[0]))
                Result_anno_val.append(list(Y_val_np[0]))
            
            Result_pred_test, Result_anno_test = [], []
            for idx, batch in enumerate(test_loader):
                X_test, Y_test = batch
                X_test, Y_test = X_test.to(DEVICE), Y_test.to(DEVICE)

                Y_pred_test = model(X_test)
                Y_test = Y_test.squeeze(-1)
                test_loss = criterion(Y_pred_test, Y_test)

                LOSS_TRACE_FOR_TEST.append(LOSS_val.cpu().detach().numpy())

                Y_pred_test_np  = Y_pred_test.to('cpu').detach().numpy()
                Y_pred_test_np  = np.argmax(Y_pred_test_np, axis=1).reshape(-1, 1)
                Y_test_np       = Y_test.to('cpu').detach().numpy().reshape(-1, 1)
                
                Result_pred_test.append(list(Y_pred_test_np[0]))
                Result_anno_test.append(list(Y_test_np[0]))

            ACC_VAL        = metrics.accuracy_score(Result_anno_val, Result_pred_val)
            ACC_TEST       = metrics.accuracy_score(Result_anno_test, Result_pred_test)

            AVG_LOSS_TRAIN = np.average(LOSS_TRACE_FOR_TRAIN)
            AVG_LOSS_VAL   = np.average(LOSS_TRACE_FOR_VAL)
            AVG_LOSS_TEST  = np.average(LOSS_TRACE_FOR_TEST)

            LOSSES_TRAIN[model_idx].append(AVG_LOSS_TRAIN)
            LOSSES_VAL[model_idx].append(AVG_LOSS_VAL)
            LOSSES_TEST[model_idx].append(AVG_LOSS_TEST)
            ACCS_VAL[model_idx].append(ACC_VAL)
            ACCS_TEST[model_idx].append(ACC_TEST)
            print(f'(epoch {epoch + 1:03d}/{EPOCHS}) Training Loss : {AVG_LOSS_TRAIN:.5f} | Validation Loss : {AVG_LOSS_VAL:.5f} | Test Loss : {AVG_LOSS_TEST:.5f} | Validation Accuracy : {ACC_VAL*100:.2f} % | Test Accuracy : {ACC_TEST*100:.2f} %')
            
    end = time.time()
    print(f"Training took {end-start:.2f} sec")
# Out:
# EPOCHS:   0%|          | 0/50 [00:00<?, ?it/s]
# (epoch 001/50) Training Loss : 2.12305 | Validation Loss : 2.00478 | Test Loss : 2.04641 | Validation Accuracy : 30.00 % | Test Accyracy : 50.00 %
# (epoch 002/50) Training Loss : 1.96715 | Validation Loss : 1.93406 | Test Loss : 1.95267 | Validation Accuracy : 40.00 % | Test Accyracy : 54.00 %
# (epoch 003/50) Training Loss : 1.91815 | Validation Loss : 1.90141 | Test Loss : 1.92621 | Validation Accuracy : 43.33 % | Test Accyracy : 55.00 %
# (epoch 004/50) Training Loss : 1.89027 | Validation Loss : 1.87002 | Test Loss : 1.89073 | Validation Accuracy : 46.67 % | Test Accyracy : 60.00 %
# (epoch 005/50) Training Loss : 1.84914 | Validation Loss : 1.82387 | Test Loss : 1.84188 | Validation Accuracy : 50.00 % | Test Accyracy : 63.00 %
# (epoch 006/50) Training Loss : 1.81380 | Validation Loss : 1.80341 | Test Loss : 1.82350 | Validation Accuracy : 51.67 % | Test Accyracy : 62.00 %
# (epoch 007/50) Training Loss : 1.79442 | Validation Loss : 1.78403 | Test Loss : 1.80522 | Validation Accuracy : 58.33 % | Test Accyracy : 63.00 %
# (epoch 008/50) Training Loss : 1.77866 | Validation Loss : 1.77346 | Test Loss : 1.79373 | Validation Accuracy : 61.67 % | Test Accyracy : 65.00 %
# (epoch 009/50) Training Loss : 1.76894 | Validation Loss : 1.76372 | Test Loss : 1.78014 | Validation Accuracy : 61.67 % | Test Accyracy : 66.00 %
# (epoch 010/50) Training Loss : 1.76240 | Validation Loss : 1.75821 | Test Loss : 1.76605 | Validation Accuracy : 61.67 % | Test Accyracy : 69.00 %
# (epoch 011/50) Training Loss : 1.75644 | Validation Loss : 1.75169 | Test Loss : 1.76376 | Validation Accuracy : 60.00 % | Test Accyracy : 71.00 %
# (epoch 012/50) Training Loss : 1.75067 | Validation Loss : 1.74551 | Test Loss : 1.77135 | Validation Accuracy : 61.67 % | Test Accyracy : 73.00 %
# (epoch 013/50) Training Loss : 1.74599 | Validation Loss : 1.74141 | Test Loss : 1.75486 | Validation Accuracy : 63.33 % | Test Accyracy : 73.00 %
# (epoch 014/50) Training Loss : 1.74184 | Validation Loss : 1.73774 | Test Loss : 1.76323 | Validation Accuracy : 61.67 % | Test Accyracy : 73.00 %
# (epoch 015/50) Training Loss : 1.73742 | Validation Loss : 1.73789 | Test Loss : 1.75313 | Validation Accuracy : 61.67 % | Test Accyracy : 72.00 %
# (epoch 016/50) Training Loss : 1.73362 | Validation Loss : 1.73413 | Test Loss : 1.75193 | Validation Accuracy : 61.67 % | Test Accyracy : 73.00 %
# (epoch 017/50) Training Loss : 1.73063 | Validation Loss : 1.72894 | Test Loss : 1.74813 | Validation Accuracy : 63.33 % | Test Accyracy : 72.00 %
# (epoch 018/50) Training Loss : 1.72749 | Validation Loss : 1.72697 | Test Loss : 1.74951 | Validation Accuracy : 61.67 % | Test Accyracy : 72.00 %
# (epoch 019/50) Training Loss : 1.72462 | Validation Loss : 1.72631 | Test Loss : 1.75624 | Validation Accuracy : 61.67 % | Test Accyracy : 72.00 %
# (epoch 020/50) Training Loss : 1.72216 | Validation Loss : 1.72281 | Test Loss : 1.74718 | Validation Accuracy : 61.67 % | Test Accyracy : 72.00 %
# (epoch 021/50) Training Loss : 1.71919 | Validation Loss : 1.72037 | Test Loss : 1.73653 | Validation Accuracy : 61.67 % | Test Accyracy : 72.00 %
# (epoch 022/50) Training Loss : 1.71792 | Validation Loss : 1.71982 | Test Loss : 1.73949 | Validation Accuracy : 61.67 % | Test Accyracy : 73.00 %
# (epoch 023/50) Training Loss : 1.71621 | Validation Loss : 1.71734 | Test Loss : 1.73159 | Validation Accuracy : 61.67 % | Test Accyracy : 73.00 %
# (epoch 024/50) Training Loss : 1.71250 | Validation Loss : 1.69847 | Test Loss : 1.71329 | Validation Accuracy : 66.67 % | Test Accyracy : 73.00 %
# (epoch 025/50) Training Loss : 1.67408 | Validation Loss : 1.66595 | Test Loss : 1.70203 | Validation Accuracy : 75.00 % | Test Accyracy : 78.00 %
# (epoch 026/50) Training Loss : 1.65229 | Validation Loss : 1.65667 | Test Loss : 1.70117 | Validation Accuracy : 76.67 % | Test Accyracy : 82.00 %
# (epoch 027/50) Training Loss : 1.64421 | Validation Loss : 1.65135 | Test Loss : 1.70177 | Validation Accuracy : 78.33 % | Test Accyracy : 81.00 %
# (epoch 028/50) Training Loss : 1.63963 | Validation Loss : 1.64632 | Test Loss : 1.70837 | Validation Accuracy : 76.67 % | Test Accyracy : 82.00 %
# (epoch 029/50) Training Loss : 1.63624 | Validation Loss : 1.64206 | Test Loss : 1.69403 | Validation Accuracy : 76.67 % | Test Accyracy : 80.00 %
# (epoch 030/50) Training Loss : 1.63261 | Validation Loss : 1.63977 | Test Loss : 1.69159 | Validation Accuracy : 76.67 % | Test Accyracy : 80.00 %
# (epoch 031/50) Training Loss : 1.63087 | Validation Loss : 1.63783 | Test Loss : 1.69958 | Validation Accuracy : 76.67 % | Test Accyracy : 80.00 %
# (epoch 032/50) Training Loss : 1.62771 | Validation Loss : 1.63309 | Test Loss : 1.69329 | Validation Accuracy : 76.67 % | Test Accyracy : 79.00 %
# (epoch 033/50) Training Loss : 1.62590 | Validation Loss : 1.63271 | Test Loss : 1.69632 | Validation Accuracy : 75.00 % | Test Accyracy : 80.00 %
# (epoch 034/50) Training Loss : 1.62314 | Validation Loss : 1.63352 | Test Loss : 1.68307 | Validation Accuracy : 76.67 % | Test Accyracy : 79.00 %
# (epoch 035/50) Training Loss : 1.62153 | Validation Loss : 1.62736 | Test Loss : 1.68371 | Validation Accuracy : 76.67 % | Test Accyracy : 80.00 %
# (epoch 036/50) Training Loss : 1.61984 | Validation Loss : 1.62638 | Test Loss : 1.69092 | Validation Accuracy : 76.67 % | Test Accyracy : 80.00 %
# (epoch 037/50) Training Loss : 1.61759 | Validation Loss : 1.62557 | Test Loss : 1.68566 | Validation Accuracy : 76.67 % | Test Accyracy : 79.00 %
# (epoch 038/50) Training Loss : 1.61625 | Validation Loss : 1.62207 | Test Loss : 1.66669 | Validation Accuracy : 76.67 % | Test Accyracy : 80.00 %
# (epoch 039/50) Training Loss : 1.61503 | Validation Loss : 1.62218 | Test Loss : 1.66685 | Validation Accuracy : 76.67 % | Test Accyracy : 80.00 %
# (epoch 040/50) Training Loss : 1.61362 | Validation Loss : 1.61886 | Test Loss : 1.65966 | Validation Accuracy : 76.67 % | Test Accyracy : 80.00 %
# (epoch 041/50) Training Loss : 1.61167 | Validation Loss : 1.62221 | Test Loss : 1.64259 | Validation Accuracy : 81.67 % | Test Accyracy : 78.00 %
# (epoch 042/50) Training Loss : 1.58563 | Validation Loss : 1.57898 | Test Loss : 1.60702 | Validation Accuracy : 85.00 % | Test Accyracy : 84.00 %
# (epoch 043/50) Training Loss : 1.56778 | Validation Loss : 1.57282 | Test Loss : 1.62367 | Validation Accuracy : 88.33 % | Test Accyracy : 84.00 %
# (epoch 044/50) Training Loss : 1.56099 | Validation Loss : 1.56654 | Test Loss : 1.60533 | Validation Accuracy : 88.33 % | Test Accyracy : 86.00 %
# (epoch 045/50) Training Loss : 1.55690 | Validation Loss : 1.56208 | Test Loss : 1.59686 | Validation Accuracy : 86.67 % | Test Accyracy : 87.00 %
# (epoch 046/50) Training Loss : 1.55303 | Validation Loss : 1.55630 | Test Loss : 1.59681 | Validation Accuracy : 86.67 % | Test Accyracy : 86.00 %
# (epoch 047/50) Training Loss : 1.54994 | Validation Loss : 1.55475 | Test Loss : 1.59376 | Validation Accuracy : 88.33 % | Test Accyracy : 87.00 %
# (epoch 048/50) Training Loss : 1.54748 | Validation Loss : 1.55723 | Test Loss : 1.58914 | Validation Accuracy : 86.67 % | Test Accyracy : 85.00 %
# (epoch 049/50) Training Loss : 1.54614 | Validation Loss : 1.55043 | Test Loss : 1.56708 | Validation Accuracy : 88.33 % | Test Accyracy : 87.00 %
# (epoch 050/50) Training Loss : 1.54296 | Validation Loss : 1.54985 | Test Loss : 1.57930 | Validation Accuracy : 86.67 % | Test Accyracy : 86.00 %
# Training took 350.82 sec
# EPOCHS:   0%|          | 0/50 [00:00<?, ?it/s]
# (epoch 001/50) Training Loss : 2.27766 | Validation Loss : 2.24283 | Test Loss : 2.21947 | Validation Accuracy : 13.33 % | Test Accyracy : 10.00 %
# (epoch 002/50) Training Loss : 2.22893 | Validation Loss : 2.21916 | Test Loss : 2.19668 | Validation Accuracy : 13.33 % | Test Accyracy : 10.00 %
# (epoch 003/50) Training Loss : 2.21459 | Validation Loss : 2.21080 | Test Loss : 2.18913 | Validation Accuracy : 31.67 % | Test Accyracy : 20.00 %
# (epoch 004/50) Training Loss : 2.20903 | Validation Loss : 2.20744 | Test Loss : 2.18618 | Validation Accuracy : 31.67 % | Test Accyracy : 20.00 %
# (epoch 005/50) Training Loss : 2.20615 | Validation Loss : 2.20537 | Test Loss : 2.18453 | Validation Accuracy : 31.67 % | Test Accyracy : 22.00 %
# (epoch 006/50) Training Loss : 2.20454 | Validation Loss : 2.20380 | Test Loss : 2.18359 | Validation Accuracy : 21.67 % | Test Accyracy : 22.00 %
# (epoch 007/50) Training Loss : 2.20338 | Validation Loss : 2.20283 | Test Loss : 2.18295 | Validation Accuracy : 21.67 % | Test Accyracy : 22.00 %
# (epoch 008/50) Training Loss : 2.20262 | Validation Loss : 2.20208 | Test Loss : 2.18234 | Validation Accuracy : 21.67 % | Test Accyracy : 22.00 %
# (epoch 009/50) Training Loss : 2.20196 | Validation Loss : 2.20154 | Test Loss : 2.18156 | Validation Accuracy : 21.67 % | Test Accyracy : 22.00 %
# (epoch 010/50) Training Loss : 2.20144 | Validation Loss : 2.20097 | Test Loss : 2.17985 | Validation Accuracy : 21.67 % | Test Accyracy : 22.00 %
# (epoch 011/50) Training Loss : 2.19946 | Validation Loss : 2.18889 | Test Loss : 2.15329 | Validation Accuracy : 21.67 % | Test Accyracy : 25.00 %
# (epoch 012/50) Training Loss : 2.15921 | Validation Loss : 2.13676 | Test Loss : 2.08838 | Validation Accuracy : 30.00 % | Test Accyracy : 26.00 %
# (epoch 013/50) Training Loss : 2.13077 | Validation Loss : 2.12343 | Test Loss : 2.07314 | Validation Accuracy : 38.33 % | Test Accyracy : 27.00 %
# (epoch 014/50) Training Loss : 2.11082 | Validation Loss : 2.09382 | Test Loss : 2.05648 | Validation Accuracy : 45.00 % | Test Accyracy : 32.00 %
# (epoch 015/50) Training Loss : 2.07623 | Validation Loss : 2.06295 | Test Loss : 2.03522 | Validation Accuracy : 46.67 % | Test Accyracy : 32.00 %
# (epoch 016/50) Training Loss : 2.05444 | Validation Loss : 2.05006 | Test Loss : 2.02529 | Validation Accuracy : 46.67 % | Test Accyracy : 32.00 %
# (epoch 017/50) Training Loss : 2.04487 | Validation Loss : 2.04283 | Test Loss : 2.02046 | Validation Accuracy : 46.67 % | Test Accyracy : 32.00 %
# (epoch 018/50) Training Loss : 2.03647 | Validation Loss : 2.03154 | Test Loss : 2.00374 | Validation Accuracy : 40.00 % | Test Accyracy : 35.00 %
# (epoch 019/50) Training Loss : 2.01494 | Validation Loss : 2.00227 | Test Loss : 1.95888 | Validation Accuracy : 51.67 % | Test Accyracy : 48.00 %
# (epoch 020/50) Training Loss : 1.99102 | Validation Loss : 1.98686 | Test Loss : 1.93412 | Validation Accuracy : 51.67 % | Test Accyracy : 49.00 %
# (epoch 021/50) Training Loss : 1.97926 | Validation Loss : 1.98008 | Test Loss : 1.92540 | Validation Accuracy : 51.67 % | Test Accyracy : 49.00 %
# (epoch 022/50) Training Loss : 1.97271 | Validation Loss : 1.97638 | Test Loss : 1.92402 | Validation Accuracy : 51.67 % | Test Accyracy : 49.00 %
# (epoch 023/50) Training Loss : 1.96812 | Validation Loss : 1.97131 | Test Loss : 1.91219 | Validation Accuracy : 51.67 % | Test Accyracy : 49.00 %
# (epoch 024/50) Training Loss : 1.96507 | Validation Loss : 1.96899 | Test Loss : 1.91036 | Validation Accuracy : 51.67 % | Test Accyracy : 50.00 %
# (epoch 025/50) Training Loss : 1.96258 | Validation Loss : 1.96699 | Test Loss : 1.90762 | Validation Accuracy : 51.67 % | Test Accyracy : 50.00 %
# (epoch 026/50) Training Loss : 1.96048 | Validation Loss : 1.96603 | Test Loss : 1.90708 | Validation Accuracy : 51.67 % | Test Accyracy : 50.00 %
# (epoch 027/50) Training Loss : 1.95908 | Validation Loss : 1.96406 | Test Loss : 1.90575 | Validation Accuracy : 51.67 % | Test Accyracy : 50.00 %
# (epoch 028/50) Training Loss : 1.95776 | Validation Loss : 1.96257 | Test Loss : 1.90617 | Validation Accuracy : 51.67 % | Test Accyracy : 50.00 %
# (epoch 029/50) Training Loss : 1.95657 | Validation Loss : 1.96265 | Test Loss : 1.90437 | Validation Accuracy : 53.33 % | Test Accyracy : 50.00 %
# (epoch 030/50) Training Loss : 1.95534 | Validation Loss : 1.96134 | Test Loss : 1.90517 | Validation Accuracy : 50.00 % | Test Accyracy : 49.00 %
# (epoch 031/50) Training Loss : 1.95446 | Validation Loss : 1.96232 | Test Loss : 1.90376 | Validation Accuracy : 51.67 % | Test Accyracy : 50.00 %
# (epoch 032/50) Training Loss : 1.95380 | Validation Loss : 1.95970 | Test Loss : 1.90358 | Validation Accuracy : 50.00 % | Test Accyracy : 50.00 %
# (epoch 033/50) Training Loss : 1.95300 | Validation Loss : 1.95902 | Test Loss : 1.90214 | Validation Accuracy : 50.00 % | Test Accyracy : 50.00 %
# (epoch 034/50) Training Loss : 1.95263 | Validation Loss : 1.95766 | Test Loss : 1.89828 | Validation Accuracy : 53.33 % | Test Accyracy : 50.00 %
# (epoch 035/50) Training Loss : 1.95162 | Validation Loss : 1.95743 | Test Loss : 1.89204 | Validation Accuracy : 53.33 % | Test Accyracy : 50.00 %
# (epoch 036/50) Training Loss : 1.95088 | Validation Loss : 1.95760 | Test Loss : 1.89257 | Validation Accuracy : 50.00 % | Test Accyracy : 50.00 %
# (epoch 037/50) Training Loss : 1.94984 | Validation Loss : 1.95545 | Test Loss : 1.89250 | Validation Accuracy : 53.33 % | Test Accyracy : 50.00 %
# (epoch 038/50) Training Loss : 1.94857 | Validation Loss : 1.95351 | Test Loss : 1.89332 | Validation Accuracy : 53.33 % | Test Accyracy : 52.00 %
# (epoch 039/50) Training Loss : 1.94478 | Validation Loss : 1.94351 | Test Loss : 1.88102 | Validation Accuracy : 53.33 % | Test Accyracy : 53.00 %
# (epoch 040/50) Training Loss : 1.92883 | Validation Loss : 1.91890 | Test Loss : 1.86888 | Validation Accuracy : 56.67 % | Test Accyracy : 57.00 %
# (epoch 041/50) Training Loss : 1.89599 | Validation Loss : 1.87107 | Test Loss : 1.81635 | Validation Accuracy : 63.33 % | Test Accyracy : 60.00 %
# (epoch 042/50) Training Loss : 1.84935 | Validation Loss : 1.83847 | Test Loss : 1.80247 | Validation Accuracy : 65.00 % | Test Accyracy : 66.00 %
# (epoch 043/50) Training Loss : 1.82434 | Validation Loss : 1.81652 | Test Loss : 1.79021 | Validation Accuracy : 65.00 % | Test Accyracy : 66.00 %
# (epoch 044/50) Training Loss : 1.79678 | Validation Loss : 1.78059 | Test Loss : 1.77066 | Validation Accuracy : 73.33 % | Test Accyracy : 72.00 %
# (epoch 045/50) Training Loss : 1.75964 | Validation Loss : 1.74788 | Test Loss : 1.73333 | Validation Accuracy : 75.00 % | Test Accyracy : 73.00 %
# (epoch 046/50) Training Loss : 1.73434 | Validation Loss : 1.72646 | Test Loss : 1.71829 | Validation Accuracy : 73.33 % | Test Accyracy : 77.00 %
# (epoch 047/50) Training Loss : 1.71283 | Validation Loss : 1.70599 | Test Loss : 1.69603 | Validation Accuracy : 80.00 % | Test Accyracy : 78.00 %
# (epoch 048/50) Training Loss : 1.69146 | Validation Loss : 1.68529 | Test Loss : 1.66771 | Validation Accuracy : 75.00 % | Test Accyracy : 78.00 %
# (epoch 049/50) Training Loss : 1.67472 | Validation Loss : 1.67070 | Test Loss : 1.66179 | Validation Accuracy : 80.00 % | Test Accyracy : 77.00 %
# (epoch 050/50) Training Loss : 1.66290 | Validation Loss : 1.66217 | Test Loss : 1.65631 | Validation Accuracy : 76.67 % | Test Accyracy : 79.00 %
# Training took 319.74 sec

# %%
model_name = ['MLP_ReLU', 'MLP_Sigmoid']
for i in range(len(models)):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('train and validation loss '+model_name[i])
    plt.plot(LOSSES_TRAIN[i], label = 'train')
    plt.plot(LOSSES_VAL[i], label = 'validation')
    plt.plot(LOSSES_TEST[i], label = 'test')
    plt.legend()
    plt.show()

# %%
for i in range(len(models)):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    #plt.ylim((0.7,1))
    plt.title('Accuracy '+model_name[i])
    plt.plot(ACCS_VAL[i], label = 'validation')
    plt.plot(ACCS_TEST[i], label = 'test')
    plt.legend()
plt.show()

# %%
layers = ['layer1.0.weight']#, 'layer2.0.weight', 'layer3.0.weight']
for i in range(len(models)):
    plt.ylim((0,0.01))
    plt.xlabel('Iteration')
    plt.ylabel('Magnitude')
    plt.title('Sum of Magnitude of Gradient for each Iteration')#+model_name[i])
    for layer, magnitudes in GRAD_MAG[i].items():
        if layer in layers:
            plt.plot(magnitudes, label = layer+' '+model_name[i])
    plt.legend()
plt.show()
